# %% [markdown]
# # Proyek Analisis Data: [Input Nama Dataset]
# - **Nama:** Anindya Rahima
# - **Email:** anindya.ninda.rahima@gmail.com
# - **ID Dicoding:** anindya_rahima

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# - Bagaimana demografi total peminjaman sepeda berdasarkan cuaca?
# - Apa yang dapat mempengaruhi pesepeda agar lebih sering bersepeda?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
day_df = pd.read_csv("day.csv", delimiter=",")

# %%
hour_df = pd.read_csv("hour.csv", delimiter=",")

# %%
hour_df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
day_df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# ### Assessing Data

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %%
hour_df.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
day_df.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
day_df.duplicated().sum()
# Out:
# 0

# %%
hour_df.duplicated().sum()
# Out:
# 0

# %%
day_df.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %%
hour_df.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %% [markdown]
# ### Cleaning Data

# %%
datetime_columns = ["dteday"]

for column in datetime_columns:
  day_df[column] = pd.to_datetime(day_df[column])

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    datetime64[ns]
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(11)
# memory usage: 91.5 KB

# %%
df = pd.read_csv("hour.csv")
df.drop_duplicates(inplace=True)

# %%
df = pd.read_csv("day.csv")
df.drop_duplicates(inplace=True)

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %%
day_df.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %%
hour_df.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Bagaimana demografi total peminjaman sepeda berdasarkan cuaca?

# %%
byweather_df = day_df.groupby(by="weathersit").cnt.sum().reset_index()
byweather_df.weathersit.replace(1, "Clear", inplace=True)
byweather_df.weathersit.replace(2, "Cloudy", inplace=True)
byweather_df.weathersit.replace(3, "Light rain", inplace=True)
byweather_df.weathersit.replace(4, "Heavy rain", inplace=True)

byweather_df.rename(columns={
    "weathersit": "Weather",
    "cnt": "Total_user"
}, inplace=True)

byweather_df
# Out:
#       Weather  Total_user
# 0       Clear     2257952
# 1      Cloudy      996858
# 2  Light rain       37869

# %%
import seaborn as sns
plt.figure(figsize=(10, 4))

sns.barplot(
    y="Weather",
    x="Total_user",
    data=byweather_df.sort_values(by="Total_user", ascending=False)
)
plt.title("Total Sharing by Weather", loc="center", fontsize=15)
plt.xlabel("Average sharing")
plt.ylabel("Weather")
# Out:
# Text(0, 0.5, 'Weather')

# %% [markdown]
# ### Pertanyaan 2: Apa yang dapat mempengaruhi pesepeda agar lebih sering bersepeda?

# %%
day_df = pd.read_csv('day.csv')

# %%
day_df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
fix_df = day_df.groupby(by="dteday").cnt.sum()

# %%
import statsmodels.api as sm

# %%
day_df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
day_df.corr()['cnt']
# Out:
# <ipython-input-26-4a5caf50a23d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   day_df.corr()['cnt']
# instant       0.628830
# season        0.406100
# yr            0.566710
# mnth          0.279977
# holiday      -0.068348
# weekday       0.067443
# workingday    0.061156
# weathersit   -0.297391
# temp          0.627494
# atemp         0.631066
# hum          -0.100659
# windspeed    -0.234545
# casual        0.672804
# registered    0.945517
# cnt           1.000000
# Name: cnt, dtype: float64

# %%
day_df.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
X = day_df[['temp','atemp']]
Y = day_df['cnt']

# %%
X = sm.add_constant(X)
reg_res = sm.OLS(Y,X).fit()
reg_res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.398
# Model:                            OLS   Adj. R-squared:                  0.397
# Method:                 Least Squares   F-statistic:                     241.1
# Date:                Mon, 04 Mar 2024   Prob (F-statistic):           4.62e-81
# Time:                        14:10:36   Log-Likelihood:                -6383.9
# No. Observations:                 731   AIC:                         1.277e+04
# Df Residuals:                     728   BIC:                         1.279e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        981.0365    188.362      5.208      0.000     611.238    1350.835
# ...

# %%
alpha = reg_res.params['const']
print('The constant term for the regression line is ' +str(round(alpha,2)))
# Out:
# The constant term for the regression line is 981.04

# %%
beta1 = reg_res.params['temp']
print('We predict that one additional temp charges the user by' +str(round(beta1,3)))
# Out:
# We predict that one additional temp charges the user by1066.212

# %%
beta2 = reg_res.params['atemp']
print('We predict that one additional atemp charges the user by' +str(round(beta2,3)))
# Out:
# We predict that one additional atemp charges the user by6314.118

# %%
r_sqrd = reg_res.rsquared
print('Temp and Atemp ' +str(round(100*r_sqrd,1)) + '% of the variation in user')
# Out:
# Temp and Atemp 39.8% of the variation in user

# %%
temp_max = day_df['temp'].max()
atemp_max = day_df['atemp'].max()

reg_res.predict([1, temp_max, atemp_max])
# Out:
# array([7209.27292819])

# %%
temp_min = day_df['temp'].min()
atemp_min = day_df['atemp'].min()

reg_res.predict([1, temp_min, atemp_min])
# Out:
# array([1543.33680349])

# %%
pred = reg_res.predict(X)
day_df['pred_cnt'] = pred
day_df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt     pred_cnt
# 0   985  3643.962690
# 1   801  3602.130936
# ...

# %%
sum(day_df['cnt'] - day_df['pred_cnt'])
# Out:
# -6.921254680491984e-10

# %%
fig, ax = plt.subplots()

ax.scatter(day_df['temp'], day_df['cnt'])
ax.plot(day_df['temp'], day_df['pred_cnt'], color = 'black')

ax.set_ylabel('cnt', fontsize = 14)
ax.set_xlabel('temp', fontsize = 14)
plt.show()

# %%
X2 = X.copy()
X2.head()
# Out:
#    const      temp     atemp
# 0    1.0  0.344167  0.363625
# 1    1.0  0.363478  0.353739
# 2    1.0  0.196364  0.189405
# 3    1.0  0.200000  0.212122
# 4    1.0  0.226957  0.229270

# %%
atemp_mean = day_df['atemp'].mean()
X2['atemp'] = atemp_mean
X2.head()
# Out:
#    const      temp     atemp
# 0    1.0  0.344167  0.474354
# 1    1.0  0.363478  0.474354
# 2    1.0  0.196364  0.474354
# 3    1.0  0.200000  0.474354
# 4    1.0  0.226957  0.474354

# %%
pred_cnt_mean_wt = reg_res.predict(X2)
day_df['pred_cnt_mean_wt'] = pred_cnt_mean_wt
day_df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt     pred_cnt  pred_cnt_mean_wt
# 0   985  3643.962690       4343.118620
# ...

# %%
fig, ax = plt.subplots()

ax.scatter(day_df['temp'], day_df['cnt'], label = 'Actual User')
ax.plot(day_df['temp'], day_df['pred_cnt_mean_wt'], color = 'black', label = 'Regression line')
ax.set_title('atemp = ' +str(round(temp_mean,2)))
ax.set_ylabel('cnt', fontsize = 14)
ax.set_xlabel('temp', fontsize = 14)

ax.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-ab68a95bdb71> in <cell line: 5>()
#       3 ax.scatter(day_df['temp'], day_df['cnt'], label = 'Actual User')
#       4 ax.plot(day_df['temp'], day_df['pred_cnt_mean_wt'], color = 'black', label = 'Regression line')
# ----> 5 ax.set_title('atemp = ' +str(round(temp_mean,2)))
#       6 ax.set_ylabel('cnt', fontsize = 14)
#       7 ax.set_xlabel('temp', fontsize = 14)
#
# NameError: name 'temp_mean' is not defined

# %%
fig, ax = plt.subplots()
ax.plot(Y,Y, color = 'black')
ax.scatter(Y,pred)
ax.set_xlabel('Actual user', fontsize=14)
ax.set_ylabel('Predicted user', fontsize=14)
plt.show()

# %%
np.random.seed(1234)
size=len(day_df)
random1 = np.random.randint(100, size=(size))
random2 = np.random.randint(100, size=(size))
random3 = np.random.rand(size)

# %%
day_df['random1'] = random1
day_df['random2'] = random2
day_df['random3'] = random3

day_df.head()

# %%
day_df.corr()

# %%
X = day_df[['temp','atemp']]
Y = day_df['cnt']

X = sm.add_constant(X)
reg_res = sm.OLS(Y,X).fit()
reg_res.summary()

# %%
X = day_df[['temp', 'atemp', 'random1', 'random2', 'random3']]
Y = day_df['cnt']
X = sm.add_constant(X)
reg_res = sm.OLS(Y,X).fit()
reg_res.summary()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclution pertanyaan 1
#
# Peminjaman sepeda dalam rentang waktu 2011-2012 terjadi paling banyak saat cuaca cerah
# - Conclution pertanyaan 2
#
# Persamaan regresi antara variabel cnt dengan variabel temp dan atemp
# \begin{align*}
# Y = 702.2432 + 1122.2874	* temp + 6277.5046 * atemp
# \end{align*}
# Pada saat temp dan atemp tinggi, maka penggunaan sepeda pun akan semakin tinggi. Dapat dilihat bahwa kecenderungan pengguna sepeda akan menggunakan sepeda pada saat cuaca dingin. Maka dari itu, kita dapat menambahkan persediaan sepeda yang ada agar jumlah demand pengguna dapat terpenuhi.
